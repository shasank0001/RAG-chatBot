# %% [markdown]
# # How to improve RAG-SYSTEMS

# %% [markdown]
# ## --Improving query

# %% [markdown]
#  ### muilti Query and Query re-writting
#  in this approch we give the user query to llm and ask it to re-write the query in different ways and perform retivel on all quetions and take all the uniqe pages from it and use those pages
#
# ![download.png](attachment:download.png)
#
# ### --query translation
#             -
# ### -- query decompsition
#
# in this approch we take the user query and divide into sub-querys and solve each query at a time
# ![download2.png](attachment:download2.png)
#
# ### step back-query
# in these approch we change the query into more abstract question and perform retrivel on both query and make our system prompt
#
# ## HYDE
# the idea in this approch is to generate a hypothetical doc based on the user query and use that doc to retrive the pages from vector store we do this becaus the when we embbed quetions it may not be near vector to our related pages so we use that generated doc for retrival
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Query Routing
#
# -- check the doc

# %% [markdown]
# ## Chunking and Indexing
#
# ### Multi-representation Indexing
#
# ![image.png](attachment:image.png)
