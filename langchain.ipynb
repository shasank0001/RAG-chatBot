# %%
from langchain_ollama import OllamaLLM

# %%
LOCL_MODEL = "deepseek-r1:8b"
model = Ollama(model=LOCL_MODEL)
model.invoke("Tell me a good joke")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 LOCL_MODEL = "llama3.2:latest"
# ----> 2 model = Ollama(model=LOCL_MODEL)
#       3 model.invoke("Tell me a good joke")
#
# NameError: name 'Ollama' is not defined
